# %% [markdown]
# # Copyright Information

# %%
# Copyright 2026 NURE Generative Neural Networks and their applications. All Rights Reserved.
#
#This notebook is based on Lab3 from
# © MIT Introduction to Deep Learning
# http://introtodeeplearning.com
#
# Licensed under the MIT License. You may not use this file except in compliance
# with the License. Use and/or modification of this code outside of NURE Generative Neural Networks
# and their applications must reference:
#
# @ NURE Generative Neural Networks and their applications
# © MIT Introduction to Deep Learning
# http://introtodeeplearning.com
#

# %% [markdown]
# # Sources
# <table align="center">
#   <td align="center"><a target="_blank" href="http://introtodeeplearning.com">
#         <img src="https://i.ibb.co/Jr88sn2/mit.png" style="padding-bottom:5px;" />
#       Visit MIT Deep Learning</a></td>
#   <td align="center"><a target="_blank" href="https://colab.research.google.com/github/MITDeepLearning/introtodeeplearning/blob/master/lab3/solutions/LLM_Finetuning_Solution.ipynb">
#         <img src="https://i.ibb.co/2P3SLwK/colab.png"  style="padding-bottom:5px;" />Run in Google Colab</a></td>
#   <td align="center"><a target="_blank" href="https://github.com/MITDeepLearning/introtodeeplearning/blob/master/lab3/solutions/LLM_Finetuning_Solution.ipynb">
#         <img src="https://i.ibb.co/xfJbPmL/github.png"  height="70px" style="padding-bottom:5px;"  />View Source on GitHub</a></td>
# </table>

# %% [markdown]
# # Laboratory 1: Large Language Model (LLM) Fine-tuning
#
# In this lab, you will fine-tune a multi-billion parameter large language model (LLM). We will go through several fundamental concepts of LLMs, including tokenization, templates, and fine-tuning. This lab provides a complete pipeline for fine-tuning a language model to generate responses in a specific style, and you will explore not only language model fine-tuning, but also ways to evaluate the performance of a language model.
#
# You will use [Liquid AI's](https://www.liquid.ai/) [LFM2-1.2B](https://huggingface.co/LiquidAI/LFM2-1.2B) as the base language model to fine-tune; Qwen's [Qwen3-Next-80B-A3B-Instruct](https://huggingface.co/Qwen/Qwen3-Next-80B-A3B-Instruct) model as an evaluation "judge" model; and Comet ML's [Opik](https://www.comet.com/site/products/opik/) as a framework for streamlined LLM evaluation.
#
# First, let's download the MIT deep learning package, install dependencies, and import the relevant packages we'll need for this lab.

# %%
# Install and import MIT Deep Learning utilities
# !pip install mitdeeplearning
# !pip install torchao==0.16.0

import mitdeeplearning as mdl
# Out:
# Requirement already satisfied: mitdeeplearning in /usr/local/lib/python3.12/dist-packages (0.7.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mitdeeplearning) (2.0.2)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from mitdeeplearning) (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from mitdeeplearning) (4.67.3)
# Requirement already satisfied: gym in /usr/local/lib/python3.12/dist-packages (from mitdeeplearning) (0.25.2)
# Requirement already satisfied: opik in /usr/local/lib/python3.12/dist-packages (from mitdeeplearning) (2.0.58)
# Requirement already satisfied: openai in /usr/local/lib/python3.12/dist-packages (from mitdeeplearning) (2.40.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from mitdeeplearning) (5.9.0)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (from mitdeeplearning) (4.0.0)
# Requirement already satisfied: peft in /usr/local/lib/python3.12/dist-packages (from mitdeeplearning) (0.19.1)
# Requirement already satisfied: lion-pytorch in /usr/local/lib/python3.12/dist-packages (from mitdeeplearning) (0.2.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets->mitdeeplearning) (3.29.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets->mitdeeplearning) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets->mitdeeplearning) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets->mitdeeplearning) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets->mitdeeplearning) (2.32.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets->mitdeeplearning) (3.7.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets->mitdeeplearning) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets->mitdeeplearning) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from datasets->mitdeeplearning) (1.17.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets->mitdeeplearning) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets->mitdeeplearning) (6.0.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gym->mitdeeplearning) (3.1.2)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.12/dist-packages (from gym->mitdeeplearning) (0.1.0)
# Requirement already satisfied: torch>=1.6 in /usr/local/lib/python3.12/dist-packages (from lion-pytorch->mitdeeplearning) (2.11.0+cu128)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai->mitdeeplearning) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai->mitdeeplearning) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai->mitdeeplearning) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai->mitdeeplearning) (0.15.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from openai->mitdeeplearning) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai->mitdeeplearning) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.12/dist-packages (from openai->mitdeeplearning) (4.15.0)
# Requirement already satisfied: boto3-stubs>=1.34.110 in /usr/local/lib/python3.12/dist-packages (from boto3-stubs[bedrock-runtime]>=1.34.110->opik->mitdeeplearning) (1.43.24)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from opik->mitdeeplearning) (8.4.1)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from opik->mitdeeplearning) (3.14.5)
# Requirement already satisfied: litellm!=1.81.*,!=1.82.*,!=1.83.0,!=1.83.1,!=1.83.2,!=1.83.3,!=1.83.4,!=1.83.5,!=1.83.6,>=1.79.2 in /usr/local/lib/python3.12/dist-packages (from opik->mitdeeplearning) (1.88.0)
# Requirement already satisfied: pydantic-settings!=2.9.0,<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from opik->mitdeeplearning) (2.14.1)
# Requirement already satisfied: pytest in /usr/local/lib/python3.12/dist-packages (from opik->mitdeeplearning) (8.4.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from opik->mitdeeplearning) (13.9.4)
# Requirement already satisfied: sentry_sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from opik->mitdeeplearning) (2.61.1)
# Requirement already satisfied: tenacity in /usr/local/lib/python3.12/dist-packages (from opik->mitdeeplearning) (9.1.4)
# Requirement already satisfied: uuid6 in /usr/local/lib/python3.12/dist-packages (from opik->mitdeeplearning) (2025.0.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from opik->mitdeeplearning) (3.1.6)
# Requirement already satisfied: watchfiles<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from opik->mitdeeplearning) (1.2.0)
# Requirement already satisfied: tree-sitter<1.0,>=0.23 in /usr/local/lib/python3.12/dist-packages (from opik->mitdeeplearning) (0.25.2)
# Requirement already satisfied: tree-sitter-javascript<1.0,>=0.23 in /usr/local/lib/python3.12/dist-packages (from opik->mitdeeplearning) (0.25.0)
# Requirement already satisfied: tree-sitter-typescript<1.0,>=0.23 in /usr/local/lib/python3.12/dist-packages (from opik->mitdeeplearning) (0.23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from peft->mitdeeplearning) (5.9.5)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from peft->mitdeeplearning) (1.13.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from peft->mitdeeplearning) (0.7.0)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers->mitdeeplearning) (0.22.2)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from transformers->mitdeeplearning) (0.25.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai->mitdeeplearning) (3.18)
# Requirement already satisfied: botocore-stubs in /usr/local/lib/python3.12/dist-packages (from boto3-stubs>=1.34.110->boto3-stubs[bedrock-runtime]>=1.34.110->opik->mitdeeplearning) (1.43.14)
# Requirement already satisfied: types-s3transfer in /usr/local/lib/python3.12/dist-packages (from boto3-stubs>=1.34.110->boto3-stubs[bedrock-runtime]>=1.34.110->opik->mitdeeplearning) (0.16.0)
# Requirement already satisfied: mypy-boto3-bedrock-runtime<1.44.0,>=1.43.0 in /usr/local/lib/python3.12/dist-packages (from boto3-stubs[bedrock-runtime]>=1.34.110->opik->mitdeeplearning) (1.43.17)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets->mitdeeplearning) (3.14.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai->mitdeeplearning) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai->mitdeeplearning) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai->mitdeeplearning) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets->mitdeeplearning) (1.5.0)
# Requirement already satisfied: fastuuid<1.0,>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from litellm!=1.81.*,!=1.82.*,!=1.83.0,!=1.83.1,!=1.83.2,!=1.83.3,!=1.83.4,!=1.83.5,!=1.83.6,>=1.79.2->opik->mitdeeplearning) (0.14.0)
# Requirement already satisfied: python-dotenv<2.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from litellm!=1.81.*,!=1.82.*,!=1.83.0,!=1.83.1,!=1.83.2,!=1.83.3,!=1.83.4,!=1.83.5,!=1.83.6,>=1.79.2->opik->mitdeeplearning) (1.2.2)
# Requirement already satisfied: tiktoken<1.0,>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from litellm!=1.81.*,!=1.82.*,!=1.83.0,!=1.83.1,!=1.83.2,!=1.83.3,!=1.83.4,!=1.83.5,!=1.83.6,>=1.79.2->opik->mitdeeplearning) (0.13.0)
# Requirement already satisfied: importlib-metadata<9.0,>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from litellm!=1.81.*,!=1.82.*,!=1.83.0,!=1.83.1,!=1.83.2,!=1.83.3,!=1.83.4,!=1.83.5,!=1.83.6,>=1.79.2->opik->mitdeeplearning) (8.7.1)
# Requirement already satisfied: jsonschema<5.0,>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from litellm!=1.81.*,!=1.82.*,!=1.83.0,!=1.83.1,!=1.83.2,!=1.83.3,!=1.83.4,!=1.83.5,!=1.83.6,>=1.79.2->opik->mitdeeplearning) (4.26.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->opik->mitdeeplearning) (3.0.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai->mitdeeplearning) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai->mitdeeplearning) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai->mitdeeplearning) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets->mitdeeplearning) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets->mitdeeplearning) (2.5.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->lion-pytorch->mitdeeplearning) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->lion-pytorch->mitdeeplearning) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->lion-pytorch->mitdeeplearning) (3.6.1)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.6->lion-pytorch->mitdeeplearning) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->lion-pytorch->mitdeeplearning) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->lion-pytorch->mitdeeplearning) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->lion-pytorch->mitdeeplearning) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->lion-pytorch->mitdeeplearning) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->lion-pytorch->mitdeeplearning) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6->lion-pytorch->mitdeeplearning) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.6->lion-pytorch->mitdeeplearning) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.6->lion-pytorch->mitdeeplearning) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.6->lion-pytorch->mitdeeplearning) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.6->lion-pytorch->mitdeeplearning) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.6->lion-pytorch->mitdeeplearning) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.6->lion-pytorch->mitdeeplearning) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.6->lion-pytorch->mitdeeplearning) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.6->lion-pytorch->mitdeeplearning) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.6->lion-pytorch->mitdeeplearning) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.6->lion-pytorch->mitdeeplearning) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.6->lion-pytorch->mitdeeplearning) (12.8.90)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers->mitdeeplearning) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->transformers->mitdeeplearning) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->opik->mitdeeplearning) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->opik->mitdeeplearning) (2.20.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets->mitdeeplearning) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets->mitdeeplearning) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets->mitdeeplearning) (2026.2)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.12/dist-packages (from pytest->opik->mitdeeplearning) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.12/dist-packages (from pytest->opik->mitdeeplearning) (1.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->mitdeeplearning) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->mitdeeplearning) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->mitdeeplearning) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->mitdeeplearning) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->mitdeeplearning) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->mitdeeplearning) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->mitdeeplearning) (1.24.2)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=1.6->lion-pytorch->mitdeeplearning) (1.5.5)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<9.0,>=8.0.0->litellm!=1.81.*,!=1.82.*,!=1.83.0,!=1.83.1,!=1.83.2,!=1.83.3,!=1.83.4,!=1.83.5,!=1.83.6,>=1.79.2->opik->mitdeeplearning) (4.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0,>=4.0.0->litellm!=1.81.*,!=1.82.*,!=1.83.0,!=1.83.1,!=1.83.2,!=1.83.3,!=1.83.4,!=1.83.5,!=1.83.6,>=1.79.2->opik->mitdeeplearning) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0,>=4.0.0->litellm!=1.81.*,!=1.82.*,!=1.83.0,!=1.83.1,!=1.83.2,!=1.83.3,!=1.83.4,!=1.83.5,!=1.83.6,>=1.79.2->opik->mitdeeplearning) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0,>=4.0.0->litellm!=1.81.*,!=1.82.*,!=1.83.0,!=1.83.1,!=1.83.2,!=1.83.3,!=1.83.4,!=1.83.5,!=1.83.6,>=1.79.2->opik->mitdeeplearning) (2026.5.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->opik->mitdeeplearning) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets->mitdeeplearning) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.6->lion-pytorch->mitdeeplearning) (1.3.0)
# Requirement already satisfied: types-awscrt in /usr/local/lib/python3.12/dist-packages (from botocore-stubs->boto3-stubs>=1.34.110->boto3-stubs[bedrock-runtime]>=1.34.110->opik->mitdeeplearning) (0.34.1)
# Requirement already satisfied: torchao==0.16.0 in /usr/local/lib/python3.12/dist-packages (0.16.0)

# %%
import os
import json
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

import torch
from torch.nn import functional as F
from torch.utils.data import DataLoader

from transformers import AutoTokenizer, AutoModelForCausalLM
from datasets import load_dataset
from peft import LoraConfig, get_peft_model
from lion_pytorch import Lion
from itertools import islice

# %%
from transformers import set_seed
import random
SEED = 999 # your seed value
set_seed(SEED)
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %% [markdown]
# # Part 1: Fine-tuning an LLM for style
#
# In the first part of this lab, we will fine-tune an LLM as a chatbot that can generate responses in a specific style. We will use the [Liquid AI LFM2-1.2B model](https://huggingface.co/LiquidAI/LFM2-1.2B) as the base language model to finetune.

# %% [markdown]
# ## 1.1: Templating and tokenization
#
# ### 1.1.1: Templating
#
# Language models that function as chatbots are able to generate responses to user queries -- but how do they do this? We need to provide them with a way to understand the conversation and generate responses in a coherent manner -- some structure of what are inputs and outputs.
#
# [Templating](https://huggingface.co/docs/transformers/main/chat_templating) is a way to format inputs and outputs in a consistent structure that a language model can understand. It involves adding special tokens or markers to indicate different parts of the conversation, like who is speaking and where turns begin and end. This structure helps the model learn the proper format for generating responses and maintain a coherent conversation flow. Without templates, the model may not know how to properly format its outputs or distinguish between different speakers in a conversation.
#
# Let's start by defining some basic templates for the LFM2-based chatbot, for turns where the user asks a question and the model responds with an answer.

# %%
# Basic question-answer template
template_without_answer = "<|startoftext|><|im_start|>user\n{question}<|im_end|>\n<|im_start|>assistant\n"
template_with_answer = template_without_answer + "{answer}<|im_end|>\n"

# Let's try to put something into the template to see how it looks
print(template_with_answer.format(question="What is your name?", answer="My name is Lili!"))
# Out:
# <|startoftext|><|im_start|>user
# What is your name?<|im_end|>
# <|im_start|>assistant
# My name is Lili!<|im_end|>

# %% [markdown]
# ### 1.1.2: Tokenization
#
# To operate on language, we need to prepare the text for the model. Fundamentally we can think of language as a sequence of "chunks" of text. We can split the text into individual chunks, and then map these chunks to numerical tokens -- collectively this is the process of [tokenization](https://huggingface.co/docs/transformers/main/tokenizer_summary). Numerical tokens can then be fed into a language model.
#
# There are several common approaches to tokenizing natural language text:
#
# 1. **Word-based tokenization**: splits text into individual words. While simple, this can lead to large vocabularies and does not handle unknown words well.
#
# 2. **Character-based tokenization**: splits text into individual characters. While this involves a very small vocabulary, it produces long sequences and loses word-level meaning.
#
# 3. **Subword tokenization**: breaks words into smaller units (subwords) based on their frequency. The most popular and commonly used approach is [byte-pair encoding (BPE)](https://en.wikipedia.org/wiki/Byte_pair_encoding), which iteratively merges the most frequent character pairs. Modern language models typically use subword tokenization as it balances vocabulary size and sequence length while handling unknown words effectively by breaking them into known subword units.
#
# In this lab we will use the tokenizer from the LFM2 model, which uses BPE. Let's load it and inspect it.

# %%
# Load the tokenizer for Liquid AI LFM2-1.2B
model_id = "LiquidAI/LFM2-1.2B"
tokenizer = AutoTokenizer.from_pretrained(model_id)

# How big is the tokenizer?
print(f"Vocab size: {len(tokenizer.get_vocab())}")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:112: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/1.00k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/91.6k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/4.73M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/434 [00:00<?, ?B/s]
# chat_template.jinja:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# Vocab size: 64400

# %% [markdown]
# We not only need to be able to tokenize the text into tokens (encode), but also de-tokenize the tokens back into text (decode). Our tokenizer will have:
# 1. an `encode` function to tokenize the text into tokens, and
# 2. a `decode` function to de-tokenize back to text so that we can read out the model's outputs.
#
# Let's test out both steps and inspect to get a better understanding of how this works.

# %%
# Lets test out both steps:
text = "Here is some sample text!"
print(f"Original text: {text}")

# Tokenize the text
tokens = tokenizer.encode(text, return_tensors="pt")
print(f"Encoded tokens: {tokens}")

# Decode the tokens
decoded_text = tokenizer.decode(tokens[0], skip_special_tokens=True)
print(f"Decoded text: {decoded_text}")
# Out:
# Original text: Here is some sample text!
# Encoded tokens: tensor([[   1, 9151,  856, 1429, 6643, 3304,  510]])
# Decoded text: Here is some sample text!

# %% [markdown]
# This is really cool. Now we have a way to move in and out of the token space.
#
# To "chat" with our LLM chatbot, we need to use the tokenizer and the chat template together, in order for the model to respond to the user's question. We can use the templates defined earlier to construct a prompt for the model, without the answer.

# %%
prompt = template_without_answer.format(question="What is the capital of France? Use one word.")
print(prompt)
# Out:
# <|startoftext|><|im_start|>user
# What is the capital of France? Use one word.<|im_end|>
# <|im_start|>assistant

# %% [markdown]
# If we were to feed this to the model, it would see that it is now the start of the model's turn, and it would generate the answer to this question.

# %% [markdown]
# ## 1.2: Getting started with the LLM
#
# Now that we have a way to prepare our data, we're ready to work with our LLM!
#
# LLMs like LFM2 are trained on a large corpus of text, on the task of predicting the next token in a sequence, given the previous tokens. We call this training task "next token prediction"; you may also see it called "causal language modeling" or "autoregressive language modeling". We can leverage models trained in this way to generate new text by sampling from the predicted probability distribution over the next token.
#
# Let's load the LFM2 model and start working with it. We will construct a prompt in chat template form and tokenize it. Then, we will feed it to the model to predict next token probabilities. Finally, we will get the next token (which is still numerical) and decode it to text.

# %%
# Load the model -- note that this may take a few minutes
model = AutoModelForCausalLM.from_pretrained(model_id, device_map="auto")
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]

# %%
### Putting it together to prompt the model and generate a response ###

# 1. Construct the prompt in chat template form
question = "What is the capital of France? Use one word."
prompt = template_without_answer.format(question=question)

# 2. Tokenize the prompt
tokens = tokenizer.encode(prompt, return_tensors="pt").to(model.device)

# 3. Feed through the model to predict the next token probabilities
with torch.no_grad():
    output = model(tokens)

    probs = F.softmax(output.logits, dim=-1)

# 4. Get the next token, according to the maximum probability
next_token = torch.argmax(probs[0, -1, :]).item()

# 5. Decode the next token
next_token_text = tokenizer.decode(next_token)

print(f"Prompt: {prompt}")
print(f"Predicted next token: {next_token_text}")
# Out:
# Prompt: <|startoftext|><|im_start|>user
# What is the capital of France? Use one word.<|im_end|>
# <|im_start|>assistant
#
# Predicted next token: Paris

# %% [markdown]
# Note that the model is not able to predict the answer to the question, it is only able to predict the next token in the sequence! For more complex questions, we can't just generate one token, but rather we need to generate a sequence of tokens.
#
# This can be done by doing the process above iteratively, step by step -- after each step we feed the generated token back into the model and predict the next token again.
#
# Instead of doing this manually ourselves, we can use the model's built-in [`model.generate()`](https://huggingface.co/docs/transformers/main/en/main_classes/text_generation#transformers.GenerationMixin.generate) functionality (supported by HuggingFace's Transformers library) to generate `max_new_tokens` number of tokens, and decode the output back to text.

# %%
prompt = template_without_answer.format(question="What does MIT stand for?")
tokens = tokenizer.encode(prompt, return_tensors="pt").to(model.device)
output = model.generate(tokens, max_new_tokens=20)
print(tokenizer.decode(output[0]))
# Out:
# <|startoftext|><|startoftext|><|im_start|>user
# What does MIT stand for?<|im_end|>
# <|im_start|>assistant
# MIT stands for Massachusetts Institute of Technology. It is a private, research-intensive university located in

# %% [markdown]
# Now we have the basic pipeline for generating text with an LLM!

# %% [markdown]
# ## 1.3: Monitoring with Comet
#
# We will be using [Comet Opik platform](https://www.comet.com/docs/opik/python-sdk-reference/) to track our model development and training runs.
# We can also use [Comet Opik platform](https://www.comet.com/docs/opik/python-sdk-reference/) to monitor our LLM once it live in deployment. This makes it easy to track the same metrics consistently across both development and deployment.
#
# First, sign up for a Comet account [at this link](https://www.comet.com/signup?from=llm&utm_source=mit_dl&utm_medium=notebook&utm_campaign=opik
# ) (you can use your Google or Github account). You will need to generate a new personal API Key, which you can find either in the first 'Get Started with Comet' page, under your account settings, or by pressing the '?' in the top right corner and then 'Quickstart Guide'. Enter this API key as the global variable `OPIK_API_KEY`.
#
# We will configure Opik by setting the API key and naming our Opik project.
#
# You also need to create one [workspace](https://www.comet.com/account-settings/workspaces) in Comet and put it to the `os.environ` also

# %%
import opik
from opik import opik_context
OPIK_API_KEY = ""

os.environ["OPIK_API_KEY"] = OPIK_API_KEY # TODO: add your OPIK or Comet API key here
assert OPIK_API_KEY != "", "You must set your OPIK or Comet API key before running this cell!"

# Set the project name for Opik
os.environ["OPIK_PROJECT_NAME"] = "ab1"

# Set the workspace name
os.environ["OPIK_WORKSPACE"] = "nure"

opik.configure()
opik_client = opik.Opik()
# Out:
# OPIK: Existing Opik clients will not use updated values for "url", "api_key", "workspace".
# OPIK: Opik is already configured. You can check the settings by viewing the config file at /root/.opik.config
# OPIK: Configuration completed successfully. Traces will be logged to 'ab1' project. To change the destination project, see: https://www.comet.com/docs/opik/tracing/log_traces#configuring-the-project-name
# Set up the Opik MCP server for an AI assistant (Claude Code, Cursor, VS Code)? (y/N) n

# %% [markdown]
# ## 1.4: Fine-tuning
#
# Fine-tuning is a technique that allows us to adapt a pre-trained neural network to better suit a downstream task, domain, or style, by training the model further on new data. By training the model further on a carefully curated dataset, we can modify its behavior, style, or capabilities. Fine-tuning is used in a variety of applications, not just language modeling. But in language modeling, fine-tuning can be used to:
# - Adapt the model's writing style
# - Improve performance on specific tasks or domains
# - Teach the model new capabilities or knowledge
# - Reduce unwanted behaviors or biases
#
# In this lab, you will fine-tune the LFM2 LLM to adapt the model's writing style. We will first fine-tune the LLM to chat in the style of a leprechaun.
#
# ![Let's Dance!](http://33.media.tumblr.com/3d223954ad0a77f4e98a7b87136aa395/tumblr_nlct5lFVbF1qhu7oio1_500.gif)
#
# We have prepared a question-answer dataset where the questions are in standard English style (i.e. "base" style) and the answers are in "leprechaun" style (written by another LLM). Let's load the dataset and inspect it.

# %% [markdown]
# ### 1.4.1: Chat function
#
# Before we start finetuning, we will build a function to easily chat with the model, both so we can monitor its progress over the course of finetuning and also to generate responses to questions.
#
# Recall our core steps from before:
# 1. Construct the question prompt using the template
# 2. Tokenize the text
# 3. Feed the tokensthrough the model to predict the next token probabilities
# 4. Decode the predicted tokens back to text
#
# Use these steps to build out the `chat` function below.

# %%
def chat(question, max_new_tokens=32, temperature=0.7, only_answer=False, model=model):
    # 1. Construct the prompt using the template
    prompt = template_without_answer.format(question=question)


    # 2. Tokenize the text
    input_ids = tokenizer(prompt, return_tensors="pt").to(model.device)


    # 3. Feed through the model to predict the next token probabilities
    with torch.no_grad():
        outputs = model.generate(
            **input_ids,
            do_sample=True,
            max_new_tokens=max_new_tokens,
            temperature=temperature)


    # 4. Get the full token sequence from the first sample in the batch returned by the model
    full_tokens = outputs[0]

    # 5. Count how many tokens belong to the prompt
    prompt_tokens = int(input_ids["input_ids"].shape[-1])

    # 6. Compute how many tokens were generated
    completion_tokens = int(full_tokens.shape[-1] - prompt_tokens)

    # 7. Extract only the generated tokens or full_tokens depending on only_answer
    output_tokens = full_tokens[prompt_tokens:] if only_answer else full_tokens

    # 8. Decode the tokens
    result = tokenizer.decode(output_tokens, skip_special_tokens=True)

    return {
        "answer": result,
        "prompt_tokens": prompt_tokens,
        "completion_tokens": completion_tokens,
        "total_tokens": prompt_tokens + completion_tokens,
        "prompt": prompt,
    }

# %% [markdown]
# Let's try chatting with the model now to test if it works! We have a sample question here (continuing with the Irish theme); feel free to try out other questions!

# %%
# Let's try chatting with the model now to test if it works!
answer = chat(
    "What is the capital of Ireland?",
    only_answer=True,
    max_new_tokens=32,
)

print(answer["answer"])

### TODO: Experiment with asking the model different questions and temperature values, and see how it responds!
# Out:
# The capital of Ireland is Dublin.

# %% [markdown]
# ### 1.4.2: Parameter-efficient fine-tuning
#
# In fine-tuning, the weights of the model are updated to better fit the fine-tuning dataset and/or task. Updating all the weights in a language model like LFM2-1.2B -- which has ~1 billion parameters -- is computationally expensive. There are many techniques to make fine-tuning more efficient.
#
# We will use a technique called [LoRA](https://arxiv.org/abs/2106.09685) -- low-rank adaptation -- to make the fine-tuning process more efficient. LoRA is a way to fine-tune LLMs very efficiently by only updating a small subset of the model's parameters, and it works by adding trainable low-rank matrices to the model. While we will not go into the details of LoRA here, you can read more about it in the [LoRA paper](https://arxiv.org/abs/2106.09685). We will use the [`peft`](https://pypi.org/project/peft/) library to apply LoRA to the LFM model.

# %%
def apply_lora(model, lora_rank=8):
    # Define LoRA config
    # We will modify matrixes Query,Key,Value, O - mixes attention heads into one final vector
    lora_config = LoraConfig(
        r=lora_rank,
        task_type="CAUSAL_LM",
        target_modules=[
            "q_proj", "o_proj", "k_proj", "v_proj", "gate_proj", "up_proj", "down_proj"
        ],
    )

    # Apply LoRA to the model
    lora_model = get_peft_model(model, lora_config)
    return lora_model

model = apply_lora(model)

# Print the number of trainable parameters after applying LoRA
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
total_params = sum(p.numel() for p in model.parameters())
print(f"number of trainable parameters: {trainable_params}")
print(f"total parameters: {total_params}")
print(f"percentage of trainable parameters: {trainable_params / total_params * 100:.2f}%")
# Out:
# number of trainable parameters: 442368
# total parameters: 1170782976
# percentage of trainable parameters: 0.04%

# %% [markdown]
# ### 1.4.3: Forward pass and loss computation
#
# Now let's define a function to perform a forward pass through the LLM and compute the loss. The forward pass gives us the logits -- which reflect the probability distribution over the next token -- for the next token. We can compute the loss by comparing the predicted logits to the true next token -- our target label. Note that this is effectively a classification problem! So, our loss can be captured by the cross entropy loss, and we can use PyTorch's [`nn.functional.cross_entropy`](https://pytorch.org/docs/stable/generated/torch.nn.functional.cross_entropy.html) function to compute it.

# %%
def forward_and_compute_loss(model, tokens, mask, context_length=512):
    # Truncate to context length
    tokens = tokens[:, :context_length]
    mask = mask[:, :context_length]

    # Construct the input, output, and mask
    x = tokens[:, :-1]
    y = tokens[:, 1:]
    mask = mask[:, 1:]

    # Forward pass to compute logits
    logits = model(x).logits

    # Compute loss
    loss = F.cross_entropy(
        logits.view(-1, logits.size(-1)),
        y.view(-1),
        reduction="none"
    )

    # Mask out the loss for non-answer tokens
    loss = loss[mask.view(-1)].mean()

    return loss

# %% [markdown]
# ### 1.4.4: Training loop for fine-tuning
#
# With this function to compute the loss, we can now define a training loop to fine-tune the model using LoRA. This training loop has such core components:
# 1. Grab a batch of data from the dataset (using the DataLoader)
# 2. Feed the data through the model to complete a forward pass and compute the loss
# 3. Backward pass to update the model weights
#
# The data in our DataLoader is initially text, and is not structured in our question-answer template. So in step (1) we will need to format the data into our question-answer template previously defined, and then tokenize the text.
#
# We care about the model's answer to the question; the "answer" tokens are the part of the text we want to predict and compute the loss for. So, after tokenizing the text we need to denote to the model which tokens are part of the "answer" and which are part of the "question". We can do this by computing a mask for the answer tokens, and then using this mask to compute the loss.
#
# Finally, we will complete the backward pass to update the model weights.
#
# Let's put this all together in the training loop below.

# %%
### Training loop ###

def train_step(step, model, optimizer, batch, tokenizer, context_length=512):
    question = batch["instruction"][0]
    answer = batch["response_style"][0]

    # Format the question and answer into the template
    text = template_with_answer.format(question=question, answer=answer)
    # Tokenize the text and compute the mask for the answer
    ids = tokenizer(text, return_tensors="pt", return_offsets_mapping=True).to(model.device)
    mask = ids["offset_mapping"][:, :, 0] >= text.index(answer)

    # Feed the tokens through the model and compute the loss
    loss = forward_and_compute_loss(
        model=model,
        tokens=ids["input_ids"],
        mask=mask,
        context_length=context_length,
    )

    # Backward pass
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    loss_value = float(loss.item())


    return loss_value, question, answer, ids

# %%
@opik.track(name="training_run")
def train(model, dataloader, tokenizer, max_steps=200, context_length=512, learning_rate=1e-4, preview_every=10,run_name="unknown"):
    opik_context.update_current_trace(
        metadata={
            "run_name": run_name,
            "model": getattr(model, "name_or_path", "unknown"),
            "max_steps": max_steps,
        },
        tags=[run_name],
    )

    rolling_losses = []

    optimizer = Lion(model.parameters(), lr=learning_rate)

    # Training loop
    for step, batch in enumerate(dataloader):
        with opik.start_as_current_span("train_step"):
          loss_value, question, answer, ids = train_step(step, model, optimizer, batch, tokenizer, context_length=context_length)

          rolling_losses.append(loss_value)

          opik_context.update_current_span(
                  input={"question": question},
                  output={"loss": loss_value},
                  metadata={
                      "phase": "train",
                      "step": step,
                      "tokens": int(ids["input_ids"].shape[-1]),
                      "answer_chars": len(answer),
                  },
            )

        # monitor progress
        if step % preview_every == 0:
          with opik.start_as_current_span("preview_generation", type="llm"):
            preview = chat("What is the capital of France?", only_answer=True)
            opik_context.update_current_span(
                    input={"question": "What is the capital of France?"},
                    output={"answer": preview["answer"]},
                    metadata={"loss": f"{np.mean(rolling_losses):.4f}"},
            )
            print(preview["answer"])
            print(f"step {step} loss: {np.mean(rolling_losses):.4f}")
            rolling_losses = []

        if step > 0 and step % max_steps == 0:
            break

    opik_client.flush()
    return model

# %% [markdown]
# ### 2.1: Fine-tune well, you must!
#
# Our leprechaun-tuned model is already pretty good at generating responses in the leprechaun style. It must be the luck of the Irish.
#
# Let's make things more interesting by considering a different style, one that has some clear patterns but also a lot of variability and room for creativity. We will use the style of [Yoda](https://en.wikipedia.org/wiki/Yoda) from Star Wars.
#
# <img src="https://media3.giphy.com/media/v1.Y2lkPTc5MGI3NjExZHcxMGZjZzdwbGV0andseWw3c3h1ODJwOXd5NHEzbnVtMHk5YWQyayZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/IaWMz9Ln8OWvf66z6k/giphy.webp" />
#
# Your goal is to try to fine-tune your model to generate responses in the Yoda style, use the LLM judge to evaluate how well the outputs of your chat model follow Yoda speak, and then use that information to improve the model.

# %%
# Load the Yoda-speak dataset and fine-tune the model using your training function
set_seed(SEED)
old_model = model
train_loader, test_loader = mdl.lab3.create_dataloader(style="yoda")
model = train(model,train_loader, tokenizer, max_steps=1600,learning_rate=5e-5,run_name="yoda")
# Out:
# The capital of France is Paris.
# step 0 loss: 3.6719
# The capital of France is Paris. Located in the northern central part of the Country, Paris is not only the political, economic, cultural, and transport hub of
# step 10 loss: 3.6625
# The capital of France is Paris. This is a globally recognized and culturally rich city that has been the political, economic, and cultural heart of France since the Middle
# step 20 loss: 3.5812
# The capital of France is Paris. This city is not only the political and administrative center of France but also a global hub for art, fashion, gastronomy
# step 30 loss: 3.7297
# The capital of France is Paris. This magnificent city is known for its historical landmarks, artistic heritage, and cultural institutions, making it a global center for fashion,
# step 40 loss: 3.8031
# The capital of France is Paris. It is known for its historical landmarks, cultural institutions, fashion, cuisine, and art. Paris is located in the northern central
# step 50 loss: 3.4406
# The capital of France is Paris.
# step 60 loss: 3.5797
# The capital of France is Paris.
# step 70 loss: 3.5000
# The capital of France is Paris.
# step 80 loss: 2.7125
# The capital of France is Paris.
# step 90 loss: 2.9828
# The capital of France is Paris.
#
# Paris is a major global center for culture, fashion, gastronomy, the arts, science, and education.
# step 100 loss: 3.5219
# The capital of France is Paris. The capital is located in the northern central part of the country. Paris is the political, economic, and cultural center of France
# step 110 loss: 2.6500
# The capital of France is Paris. Paris is located in the northern central part of France and covers an area of 105.4 km2. It is situated
# step 120 loss: 2.9937
# Paris, France's capital and largest city, is located at the confluence of the Seine River and its tributaries, forming the Île-de-la-Cité
# step 130 loss: 2.8281
# The capital of France is Paris.
# step 140 loss: 2.8258
# The capital of France is Paris.
# step 150 loss: 2.6422
# The capital of France is Paris.
# step 160 loss: 3.0297
# The capital of France is Paris.
# step 170 loss: 2.8844
# The capital of France is Paris.
# step 180 loss: 2.7547
# Paris is the capital of France, a beautiful and historic city located in the northern part of the country.
# step 190 loss: 2.8828
# The capital of France is Paris.
# step 200 loss: 2.8375
# The capital of France is Paris.
# step 210 loss: 2.4340
# The capital of France is Paris.
# step 220 loss: 2.8937
# The capital of France is Paris.
# step 230 loss: 1.9602
# The capital of France is Paris.
# step 240 loss: 2.2703
# The capital of France is Paris, it is a beautiful city.
# step 250 loss: 2.2301
# The capital of France is Paris.
# step 260 loss: 2.7750
# Paris, the capital of France.
# It is.
# The capital of France.
# step 270 loss: 2.5477
# The capital of France, it is Paris.
# step 280 loss: 1.9695
# The capital of France is Paris.
# step 290 loss: 2.3750
# Paris, the capital city of France.
# It is, the French capital.
# It is, Paris, the capital city.
# Of France, Paris, the capital city
# step 300 loss: 2.2969
# Paris, the capital of France, is. The capital of France, Paris, is.
# step 310 loss: 2.3633
# Paris, the capital of France.
# step 320 loss: 1.9549
# Paris, the capital of France is.
# step 330 loss: 2.4287
# The capital of France, it is, Paris.
# step 340 loss: 2.1678
# Paris, the capital of France, is.
# step 350 loss: 2.0559
# Paris, the capital of France.
# step 360 loss: 2.2156
# Paris, the capital of France, is.
# step 370 loss: 2.2496
# Paris, the capital of France, is.
# step 380 loss: 1.8695
# Paris, the capital of France, it is.
# step 390 loss: 2.4273
# Paris, the capital of France, it is.
# step 400 loss: 2.5852
# Paris, the capital of France, is. It is.
# step 410 loss: 2.0355
# Paris, the capital of France is.
# step 420 loss: 1.9250
# Paris, it is, the capital of France, you see.
# step 430 loss: 2.1781
# Paris, the capital, the French capital, it is.
# step 440 loss: 2.2977
# Paris, the capital of France, is.
# step 450 loss: 2.3453
# Paris, the capital of France, it is.
# step 460 loss: 2.2016
# Paris, capital of France, it is.
# step 470 loss: 2.4320
# Capital of France, Paris.
# step 480 loss: 2.3375
# Paris, the capital of France, it is.
# step 490 loss: 1.8297
# Paris, capital of France, it is.
# step 500 loss: 2.2039
# Paris, the capital of France, is.
# step 510 loss: 2.2305
# Capital of France, Paris is. The capital of France, Paris, the capital of France, it is.
# step 520 loss: 2.5016
# Capital of France, Paris, it is.
# step 530 loss: 1.9912
# Capital of France, Paris, it is.
# step 540 loss: 2.1867
# Capital of France, Paris, is.
# step 550 loss: 2.2391
# Capital of France, Paris, Paris, France, the capital.
# step 560 loss: 2.3289
# Capital of France, Paris, in the city of Paris, France, the capital, lies in Paris.
# step 570 loss: 1.9461
# Paris, Paris, in France, it is.
# step 580 loss: 1.9973
# Paris, the capital of France, it is.
# step 590 loss: 2.3281
# Paris, the capital of France, Paris, it is.
# step 600 loss: 2.1625
# Paris, the capital of France, it is.
# step 610 loss: 2.2352
# Paris, the capital of France, is.
# step 620 loss: 2.2305
# Paris, the capital of France, it is.
# step 630 loss: 2.3711
# Paris, the capital of France, is.
# step 640 loss: 2.3207
# Paris, the capital of France is.
# step 650 loss: 1.7863
# Paris, the capital of France, is.
# step 660 loss: 2.3016
# Paris, the capital of France, is.
# step 670 loss: 2.1297
# Capital of France, Paris, it is in the city.
# step 680 loss: 2.1043
# Paris, the capital of France, is.
# step 690 loss: 2.3316
# Paris, Paris is.
# step 700 loss: 2.2930
# Paris, the capital of France, is.
# step 710 loss: 1.9278
# Paris, the capital of France, it is.
# step 720 loss: 1.9432
# Paris, the capital of France, is.
# step 730 loss: 2.0492
# Capital of France, the city, Paris, it is.
# step 740 loss: 2.5234
# Paris, the capital of France, is. The capital city of France, Paris, is.
# step 750 loss: 1.7178
# The capital of France, it is. Paris.
# step 760 loss: 2.3500
# Paris, the capital of France, is.
# step 770 loss: 2.1039
# Paris, the capital of France, is.
# step 780 loss: 2.1227
# Paris, capital of France, is.
# step 790 loss: 2.1938
# Paris, the capital of France. In Paris, you will find the Eiffel Tower, and many museums, among them the Louvre, the most famous
# step 800 loss: 2.2906
# Paris, the capital of France, is.
# step 810 loss: 2.0406
# Paris, Paris, the capital of France, it is.
# step 820 loss: 1.9049
# Lyon, the capital of France, is.
# step 830 loss: 2.4445
# Paris, the capital, of France, is.
# step 840 loss: 2.1851
# Paris, the capital of France, is.
# step 850 loss: 2.1015
# Paris, the capital of France, it is.
# step 860 loss: 2.1469
# Paris, the capital of France, is.
# step 870 loss: 1.9785
# Paris, the capital, of France, it is.
# step 880 loss: 1.8887
# Paris, the capital of France, is.
# step 890 loss: 2.0123
# Paris, the capital of France, is.
# step 900 loss: 1.9009
# Paris, the capital of France, it is.
# step 910 loss: 1.8588
# Paris, the capital of France, is.
# step 920 loss: 1.9203
# Paris, the capital of France, is.
# step 930 loss: 2.2188
# Paris, the capital of France, is.
# step 940 loss: 2.2586
# Paris, the capital of France, is.
# step 950 loss: 2.2273
# Paris, the capital of France is.
# step 960 loss: 2.1273
# Paris, the capital of France, it is.
# step 970 loss: 2.0471
# Paris, the capital of France, lies it does.
# step 980 loss: 1.5978
# Paris, the capital of France, is.
# step 990 loss: 2.1730
# Paris, the capital, the capital of France is.
# step 1000 loss: 1.7879
# Paris, the capital of France, it is.
# step 1010 loss: 1.9781
# Paris, the capital of France, it is.
# step 1020 loss: 2.6180
# Paris, the capital of France, is.
# step 1030 loss: 2.2451
# Paris, the capital of France, is.
# step 1040 loss: 1.9242
# Paris, the capital of France, it is.
# step 1050 loss: 1.6648
# Paris, the capital of France, is.
# step 1060 loss: 2.1437
# Paris, capital of France, is.
# step 1070 loss: 2.0293
# Paris, the capital of France, it is.
# step 1080 loss: 2.0047
# Paris, the capital of France, it is.
# step 1090 loss: 2.1344
# Paris, the capital of France, is.
# step 1100 loss: 1.9434
# Paris, the capital of France, is.
# step 1110 loss: 2.2375
# Paris, the capital of France, it is.
# step 1120 loss: 2.1773
# Paris, the capital of France, is.
# step 1130 loss: 2.0125
# Paris, the capital of France, is.
# step 1140 loss: 1.7694
# Paris, the capital of France, is.
# step 1150 loss: 2.1207
# Paris, the capital of France, is.
# step 1160 loss: 1.9352
# Paris, the capital of France, is.
# step 1170 loss: 2.2695
# Paris, the capital of France, is.
# step 1180 loss: 2.2391
# Capital of France, Paris, is.
# step 1190 loss: 1.8766
# Paris, the capital of France, it is.
# step 1200 loss: 2.0105
# Paris, the capital of France, is.
# step 1210 loss: 2.2531
# Paris, the capital of France, is.
# step 1220 loss: 2.2336
# Capital of France, Paris is.
# step 1230 loss: 1.7870
# Paris, the capital of France, is.
# step 1240 loss: 2.0320
# Paris, the capital of France, is.
# step 1250 loss: 2.0107
# Paris, the capital of France, it is.
# step 1260 loss: 1.5688
# Paris, the capital of France, is.
# step 1270 loss: 2.4523
# Paris, the capital of France, is it.
# step 1280 loss: 1.8426
# Paris, the capital of France is.
# step 1290 loss: 1.8146
# Paris, the capital of France, is.
# step 1300 loss: 2.0711
# Paris, the capital of France, it is.
# step 1310 loss: 1.8426
# Paris, the capital of France, it is.
# step 1320 loss: 2.1656
# Paris, the capital of France's is.
# step 1330 loss: 1.9406
# Paris, the capital of France, it is.
# step 1340 loss: 1.9754
# Paris, the capital of France, is.
# step 1350 loss: 1.4746
# Paris, the capital of France, it is.
# step 1360 loss: 1.6408
# Paris, the capital of France, is.
# step 1370 loss: 1.7246
# Paris, the capital of France, it is.
# step 1380 loss: 1.7941
# Paris, the capital city of France, is.
# step 1390 loss: 1.5680
# Paris, the capital, of France, is.
# step 1400 loss: 1.7492
# Paris, the capital of France, is.
# step 1410 loss: 1.9842
# Paris, the capital of France is.
# step 1420 loss: 2.1508
# Paris, the capital of France is.
# step 1430 loss: 1.6199
# Paris, the capital of France, is.
# step 1440 loss: 1.7848
# Paris, the capital of France, it is.
# step 1450 loss: 1.8889
# Paris, the capital of France, is.
# step 1460 loss: 2.0102
# Paris, the capital of France is.
# step 1470 loss: 1.9645
# Paris, the capital, of France, it is.
# step 1480 loss: 1.5383
# Paris, the capital of France, is.
# step 1490 loss: 1.8234
# Paris, the capital of France, it is.
# step 1500 loss: 1.8912
# Paris, the capital of France, is.
# step 1510 loss: 1.7521
# Paris, the capital of France, is.
# step 1520 loss: 1.9250
# Paris, Paris, the capital of France, it is.
# step 1530 loss: 2.0914
# Paris, the capital of France, is.
# step 1540 loss: 2.1492
# Paris, the capital of France, is.
# step 1550 loss: 2.1531
# Paris, the capital of France, it is.
# step 1560 loss: 2.0129
# Paris, the capital of France, is.
# step 1570 loss: 2.5031
# Paris, the capital of France, is.
# step 1580 loss: 2.1309
# Paris, the capital of France, is.
# step 1590 loss: 1.6730
# Capital of France, Paris is.
# step 1600 loss: 2.0063

# %% [markdown]
# Start by defining a system prompt for the judge LLM, setting the context that it will evaluate how well the outputs of your chat model follow Yoda speak. Experiment with different system prompts to see how they affect the judge LLM's evaluation! Keep in mind that a better judge LLM will give you a better evaluation of how well your Yoda model is doing, and that a better evaluation will help you improve your Yoda model.

# %%
### LLM as a judge ###

'''TODO: Experiment with different system prompts to see how they affect the judge LLM's evaluation!
        Come back to this cell after you've generated some text from your model.'''

system_prompt = """
You are an impartial judge that evaluates if text was written by {style}.

An example piece of text from {style} is:
{example}

Now, analyze some new text carefully and respond on if it follows the
same style of {style}. Be critical to identify any issues in the text.
Then convert your feedback into a number between 0 and 10: 10 if the text
is written exactly in the style of {style}, 5 if mixed faithfulness to the
style, or 0 if the text is not at all written in the style of {style}.

Directly answer with the score formatted in a dictionary.
The format of your response should only be the dictionary and nothing else:
{{"score": <score between 0 and 10>}}
"""

style = "Yoda"
example = "The very Republic is threatened, if involved the Sith are. Hard to see, the dark side is. Discover who this assassin is, we must. With this Naboo queen you must stay, Qui-Gon. Protect her. May the Force be with you. A vergence, you say? But you do! Revealed your opinion is. Trained as a Jedi, you request for him? Good, good, young one."

system_prompt = system_prompt.format(style=style, example=example)
print("=== System prompt ===")
print(system_prompt)
# Out:
# === System prompt ===
#
# You are an impartial judge that evaluates if text was written by Yoda.
#
# An example piece of text from Yoda is:
# The very Republic is threatened, if involved the Sith are. Hard to see, the dark side is. Discover who this assassin is, we must. With this Naboo queen you must stay, Qui-Gon. Protect her. May the Force be with you. A vergence, you say? But you do! Revealed your opinion is. Trained as a Jedi, you request for him? Good, good, young one.
#
# Now, analyze some new text carefully and respond on if it follows the
# same style of Yoda. Be critical to identify any issues in the text.
# Then convert your feedback into a number between 0 and 10: 10 if the text
# is written exactly in the style of Yoda, 5 if mixed faithfulness to the
# style, or 0 if the text is not at all written in the style of Yoda.
#
# Directly answer with the score formatted in a dictionary.
# The format of your response should only be the dictionary and nothing else:
# {"score": <score between 0 and 10>}

# %% [markdown]
# ### 2.2: Setting up the judge LLM
#
# In LLM as a judge, we need to use a model that is larger (and therefore more capable) than our "performer" model, in our case the style fine-tuned LFM2 1.2B. Since it is infeasible to load larger models locally into notebooks, you will gain experience interfacing with these larger LLMs through an API served on [OpenRouter](https://openrouter.ai/).
#
# You will need to sign up for an [OpenRouter account](https://openrouter.ai/sign-up) and then [generate an API key](https://openrouter.ai/keys).
#
# Through the OpenRouter interface, you will be able to experiment with different judge LLMs -- here we have suggested one possible larger LLM to get you started. Note there are free models available on OpenRouter Qwen's [Qwen3-Next-80B-A3B-Instruct:free](https://huggingface.co/Qwen/Qwen3-Next-80B-A3B-Instruct) or [gemma-2-9b-it:free](https://openrouter.ai/google/gemma-2-9b-it:free)), but these will run into rate limitations if you run them too much (no more than 20 requests per minute, 50 requests per day).
#
# We have defined a simple class, `LLMClient`, to interact with the OpenRouter API. This class has a method `ask` that takes a user prompt and returns the model's response. Keep in mind that the judge LLM's response will be conditioned on the system prompt you provide -- the system prompt is critical to set the criteria for the evaluation!

# %%
OPENROUTER_API_KEY = "" # TODO: add your OpenRouter API key here
assert OPENROUTER_API_KEY != "", "You must set your OpenRouter API key before running this cell!"

model_name = "qwen/qwen3-next-80b-a3b-instruct"
llm = mdl.lab3.LLMClient(model=model_name, api_key=OPENROUTER_API_KEY)

# %% [markdown]
# ### 2.3: Defining the evaluation metric
#
# Great! We have set up our judge LLM, but we still need to make this quantitative. We can do this by defining a metric that uses the judge LLM to score the outputs of the model. Doing this is streamlined with Comet ML's [Opik library](https://www.comet.com/docs/opik/python-sdk-reference/), a platform for LLM evaluation and benchmarking.
#
# Now we will use the Comet Opik library to define a metric that uses the judge LLM to score the outputs of the model.

# %% [markdown]
# Opik provides a framework for creating custom judge metrics as well as a varity of pre-built metrics for common evaluation tasks. These metrics are designed to help you quickly and effectively gauge the performance of your LLM outputs and include metrics such as Hallucination, Answer Relevance, Context Precision/Recall and more. You can learn more about the available metrics in the [`Metrics Overview section`](https://www.comet.com/docs/opik/evaluation/metrics/overview) of the Opik documentation.
#
# The Opik python SDK has a base class for defining metrics, [`base_metric.BaseMetric`](https://www.comet.com/docs/opik/python-sdk-reference/evaluation/metrics/BaseMetric.html). You will use this to define a custom metric that uses the judge LLM to evaluate text for how well it adheres to Yoda speak. Note that the judge LLM and the metric can be applied to any text, not just the outputs of the model. This is important to keep in mind, since we need both a negative control -- text in the "base" standard English style -- and a positive control -- training-set text in Yoda-speak style -- against which to compare the model's generations.
#
# Set the judging criteria in the system prompt, and define the `score` function to evaluate text by querying the judge LLM.

# %%
from opik.evaluation.metrics import base_metric, score_result

class LLMJudgeEvaluator(base_metric.BaseMetric):
    def __init__(self, judge: mdl.lab3.LLMClient = None, system_prompt: str = None):
        self.judge = judge
        self.system_prompt = system_prompt
        self.prompt_template = "Evaluate this text: {text}"

    def score(self, text: str, n_tries=20, **kwargs):
        """ Evaluate by asking an LLM to score it. """

        for attempt in range(n_tries):
            try:
                #Convert the text to template form before passing it to the judge LLM
                prompt = self.prompt_template.format(text=text)


                with opik.start_as_current_span("judge_call"):
                  #Call the judge LLM with the system prompt and the prompt template.
                  res = self.judge.ask(
                    system=self.system_prompt,
                    user=prompt,
                    max_tokens=20,
                  )

                  opik_context.update_current_span(
                     input={"system": self.system_prompt, "user": prompt},
                     output={"judge_raw_response": res.choices[0].message.content},
                     metadata={"phase": "judge test"},
                     model=model_name,
                     provider="openrouter",
                 )

                # Extract the assistant's content from the API response
                res = res.choices[0].message.content
                res_dict = json.loads(res)

                max_score = 10 # The maximum score that the LLM should output
                score = res_dict["score"] / max_score # Normalize
                score = max(0.0, min(score, 1.0)) # Clip between 0 and 1

                # Return the score object
                return score_result.ScoreResult(name="StyleScore", value=score)

            except Exception as e:
                if attempt == n_tries - 1:  # Last attempt
                    raise e  # Re-raise the exception if all attempts failed
                continue  # Try again if not the last attempt

# %% [markdown]
# Instantiate your Comet Opik judge using the `LLMJudgeEvaluator` class and system prompt.

# %%
set_seed(SEED)
judge = LLMJudgeEvaluator(llm, system_prompt=system_prompt)

# %% [markdown]
# ## 2.4: Evaluating the model by scoring with your judge LLM
#
# Now we can use the judge LLM to score the outputs of the model. We will use the `scoring_function` to score text using the judge LLM.
#
# Feed in a few probe sentences to get a vibe check on the judge LLM.

# %%
def scoring_function(text):
    return judge.score(text).value

test_texts = [
    "Tennis is a fun sport. But you must concentrate.",
    "Fun sport, tennis is. But work hard, you must.",
    "Hard to see, the dark side is."
]

@opik.track(name="scoring first 3 samples")
def score_test_texts(test_texts):
  for text in test_texts:
      score = scoring_function(text)
      print(f"{text} ==> Score: {score}")

score_test_texts(test_texts)
# Out:
# Tennis is a fun sport. But you must concentrate. ==> Score: 0.0
# Fun sport, tennis is. But work hard, you must. ==> Score: 0.8
# Hard to see, the dark side is. ==> Score: 1.0

# %% [markdown]
# Now we will evaluate how well our fine-tuned model is doing by scoring the outputs of the model, as well as our base-style text (negative control) and the training-set text in Yoda-speak style (positive control).
#
# Generate text from your model by asking it new questions.

# %%
# Generate text from your model by asking it new questions.

def generate_samples_from_test(test_loader, num_samples):
    samples = []
    for test_sample in tqdm(islice(test_loader, num_samples), total=num_samples):
        test_question = test_sample['instruction'][0]
        with torch.no_grad():
            generated = chat(test_question, only_answer=True, max_new_tokens=48,temperature=0.3)["answer"]
        samples.append(generated)

    return samples

n_samples = 5
generated_samples = generate_samples_from_test(test_loader, num_samples=n_samples)
# Out:
# 100%|██████████| 5/5 [00:04<00:00,  1.16it/s]

# %% [markdown]
# Let's also collect some base-style text (`base_samples`) and the training-set text in Yoda-speak style (`style_samples`). For these, we won't need to generate text, since we already have the text in the dataset.

# %%
base_samples = [sample['response'][0] for i, sample in enumerate(train_loader) if i < n_samples]
style_samples = [sample['response_style'][0] for i, sample in enumerate(train_loader) if i < n_samples]

# %% [markdown]
# Now that we have our samples, we can score them using the judge LLM.

# %%
# Score the samples
@opik.track(name="evaluation batch track")
def evaluate_samples(samples, kind):
    scores = []

    for idx, text in enumerate(samples):
        with opik.start_as_current_span(f"score_{idx}"):
            score = judge.score(text).value

            #log to Opik
            opik_context.update_current_span(
                input={"kind": kind, "text_preview": text[:300]},
                output={"score": float(score)},
                metadata={"phase": "eval", "sample_index": idx},
            )

            scores.append(score)

    opik_context.update_current_trace(
        input={"kind": kind, "num_samples": len(samples)},
        output={
            "mean_score": float(np.mean(scores)),
            "std_score": float(np.std(scores)),
        },
    )

    return scores


# Compute and print the scores for the base-style text, generated text, and training-set text in Yoda-speak style
base_scores = evaluate_samples(base_samples,"base from test")
generated_scores = evaluate_samples(generated_samples,"generated")
style_scores = evaluate_samples(style_samples,"style from test")

print(f"Base :  {np.mean(base_scores):.2f} ± {np.std(base_scores):.2f}")
print(f"Gen :   {np.mean(generated_scores):.2f} ± {np.std(generated_scores):.2f}")
print(f"Train : {np.mean(style_scores):.2f} ± {np.std(style_scores):.2f}")

opik_client.flush()
# Out:
# Base :  0.00 ± 0.00
# Gen :   0.38 ± 0.17
# Train : 0.44 ± 0.17
# True

# %% [markdown]
# Look at the average scores for each of the three types of text -- what do you observe?
#
# We can also plot the distribution of scores for each of the three types of text.

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Create a clean pandas DataFrame that combines all score groups into one table
df = pd.DataFrame({
    # Combine scores from three sources into a single column
    'Score': [*base_scores, *generated_scores, *style_scores],

    # Create a column indicating which group each score belongs to
    'Type': ['Base']*len(base_scores) +
            ['Generated']*len(generated_scores) +
            ['Style']*len(style_scores)
})

# Create a figure with a specific size
plt.figure(figsize=(8,5))

# Plot a histogram using seaborn
sns.histplot(
    data=df,
    x='Score',
    hue='Type',
    multiple='dodge',
    stat='probability',
    bins=6
)

# Label the x- and y-axis
plt.xlabel("Judge score")
plt.ylabel("Probability")
# Add a title to the plot
plt.title("Distribution of judge scores")

# Display the plot
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
# Bar plot for judge scores

# Labels for each group of scores
labels = ["Base", "Generated", "Style"]

# Compute the mean score for each group
means = [
    np.mean(base_scores),
    np.mean(generated_scores),
    np.mean(style_scores),
]

# Compute the standard deviation for each group
# These will be used as error bars in the plot
stds = [
    np.std(base_scores),
    np.std(generated_scores),
    np.std(style_scores),
]

plt.figure(figsize=(8, 5))

# Draw a bar chart of the mean scores
# yerr adds error bars representing the standard deviation
# capsize controls the width of the error bar caps
bars = plt.bar(labels, means, yerr=stds, capsize=6)

plt.ylim(0, 1)
plt.ylabel("Judge score")
plt.title("Judge LLM scores by text type")

# Add numeric labels above each bar showing the mean value
for bar, value in zip(bars, means):
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        value + 0.02,
        f"{value:.2f}",
        ha="center",
        va="bottom"
    )

# Adjust layout to prevent labels from being cut off
plt.tight_layout()

plt.show()

# %% [markdown]
# Use these observations to improve your model. Remember that the judge LLM is not perfect, and you can try to improve the judge LLM to better evaluate the model's outputs. A better judge LLM will give you a better evaluation of how well your Yoda model is doing, and that better evaluation will help you improve your Yoda model.

# %% [markdown]
# ## 2.5: Monitoring with evals
#
# Just as we used Opik for evaluation metrics during fine-tuning and testing, we can also use Opik to monitor our LLM once it is live in deployment. This makes it easy to track the same metrics consistently across both development and deployment.

# %% [markdown]
# [Tracing](https://www.comet.com/docs/opik/tracing/concepts) helps you understand the end-to-end flow of your LLM application and pinpoint specific steps that may be causing issues.
#
# In the example below, we make a sample call to the chatbot and use Opik’s `@track` decorator to log data to the Opik UI, creating a record of live calls to the application. You can add the `@track` decorator to any function to trace not only LLM calls, but also other steps in your application pipeline.

# %%
@opik.track(name="inference chat track")
def inference_chat(question, max_new_tokens=32, temperature=0.7, only_answer=False, model=model):
    with opik.start_as_current_span("generate step"):
        # Generate an answer to the question
        gen = chat(
            question,
            max_new_tokens=max_new_tokens,
            temperature=temperature,
            only_answer=only_answer,
            model=model
        )

        opik_context.update_current_span(
            input={
                "question": question,
                "temperature": temperature,
                "max_new_tokens": max_new_tokens,
                "only_answer": only_answer,
            },
            output={"answer": gen["answer"]},
            metadata={"phase": "inference"},
            usage={
                "prompt_tokens": gen["prompt_tokens"],
                "completion_tokens": gen["completion_tokens"],
                "total_tokens": gen["total_tokens"],
            },
            model=model_id,
            provider="huggingface",
        )

    with opik.start_as_current_span("style_score"):
        # Score the answer with the judge
        style_score = scoring_function(gen["answer"])

        opik_context.update_current_span(
            input={"text_preview": gen["answer"][:300]},
            output={"style_score": float(style_score)},
            metadata={"phase": "eval"},
        )

    opik_context.update_current_trace(
        input={"question": question},
        output={"answer": gen["answer"]},
        metadata={
            "temperature": temperature,
            "max_new_tokens": max_new_tokens,
            "only_answer": only_answer,
        },
        feedback_scores=[
            {
                "name": "Yoda style eval",
                "value": float(style_score),
            }
        ],
    )

    return gen["answer"]

# %% [markdown]
# Now you can make an example call to your model to see the trace logged to Opik. Once you run the cell below you should see a link to your Opik UI where your traces are logged to your project. Follow that link to see your traces in the Opik platform.

# %%
# Let's try chatting with the model now to see the traces produced with the score
answer = inference_chat(
    "Who was the only non-Jedi to wield a lightsaber in the original Star Wars trilogy?",
    only_answer=True,
    max_new_tokens=32,
)

print(answer)
# Out:
# Non-Jedi only, the only lightsaber wielder was Han Solo.

# %% [markdown]
# ## 2.6: Conclusion
#
# Experiment with both your chat model and your judge LLM to try to improve the quality of the Yoda-speak. The competition for this lab will be based on the following criteria:
# * **Likelihood of true Yoda-speak under your chat model**: the better your chat model does at understanding Yoda-speak, it will estimate a lower cross entropy loss for language that is true Yoda-speak. At the end of this lab, you will evaluate the likelihood of a held-out test-sample of true Yoda-speak under your chat model. Include this likelihood in your report. This gives us a quantitative measure to compare different chat models (which may have interacted with different judge LLMs).
# * **Experiments and changes you tried to improve your chat model**: include a description of changes you made and the results you observed.
#
# #### IMPORTANT: RUN THE FOLLOWING CELL BELOW TO PRINT THE RESULT BUT DO NOT MODIFY ITS CONTENTS.

# %% [markdown]
# # **Завдання на "добре"**
#
# 1. додати метрики якості навчання: Recall, BalancedAccuracy, StyleGain

# %%
def compute_style_metrics(style_scores, base_scores):
    P = np.array(style_scores)
    N = np.array(base_scores)

    recall = np.mean(P)
    specificity = np.mean(1 - N)
    balanced_acc = 0.5 * (recall + specificity)
    style_gain = np.mean(P) - np.mean(N)

    return {
        "Recall": recall,
        "BalancedAccuracy": balanced_acc,
        "StyleGain": style_gain
    }

metrics = compute_style_metrics(style_scores, base_scores)
print("Metrics:", metrics)
# Out:
# Metrics: {'Recall': np.float64(0.43999999999999995), 'BalancedAccuracy': np.float64(0.72), 'StyleGain': np.float64(0.43999999999999995)}

# %% [markdown]
# 2. перемішати і розділити вибірку (дивися пояснення у розділі 6) навчальних прикладів на train, validation і test, задати batch_size > 10. Порівняти результати з попередніми на основі обраних метрик.

# %%
# === Correct split with Yoda style ===

from datasets import load_dataset
from torch.utils.data import DataLoader
import random

def load_yoda_style(path="content/yoda.txt"):
    with open(path, "r", encoding="utf-8") as f:
        lines = [l.strip() for l in f.readlines() if len(l.strip()) > 0]
    return lines


def create_dataloaders_yoda(batch_size=16):
    # 1. Load base dataset
    dataset = load_dataset("databricks/databricks-dolly-15k", split="train")

    # 2. Load Yoda style
    yoda_lines = load_yoda_style()

    # 3. Shuffle dataset
    dataset = dataset.shuffle(seed=SEED)

    # 4. Build new dataset with style
    data = []
    for i, sample in enumerate(dataset):
        styled = yoda_lines[i % len(yoda_lines)]

        data.append({
            "instruction": sample["instruction"],
            "response": sample["response"],           # base
            "response_style": styled                  # Yoda style
        })

    # 5. Split 70/15/15
    N = len(data)
    train_end = int(0.7 * N)
    val_end = int(0.85 * N)

    train_data = data[:train_end]
    val_data = data[train_end:val_end]
    test_data = data[val_end:]

    # 6. Collate
    def collate_fn(batch):
        return {
            "instruction": [x["instruction"] for x in batch],
            "response": [x["response"] for x in batch],
            "response_style": [x["response_style"] for x in batch],
        }

    # 7. DataLoaders
    train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)
    val_loader = DataLoader(val_data, batch_size=batch_size, shuffle=False, collate_fn=collate_fn)
    test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=False, collate_fn=collate_fn)

    return train_loader, val_loader, test_loader


# === використання ===
train_loader, val_loader, test_loader = create_dataloaders_yoda(batch_size=16)

# нові даталоадери
train_loader, val_loader, test_loader = create_dataloaders_yoda(batch_size=16)

# важливо: перевстановлюємо seed
set_seed(SEED)

# створюємо НОВУ модель (не використовуємо стару!)
model_new = AutoModelForCausalLM.from_pretrained(model_id, device_map="auto")

# застосовуємо LoRA
model_new = apply_lora(model_new)

# тренуємо
model_new = train(
    model_new,
    train_loader,
    tokenizer,
    max_steps=1600,
    learning_rate=5e-5,
    run_name="yoda_split"
)

generated_samples_new = generate_samples_from_test(test_loader, num_samples=5)

generated_scores_new = evaluate_samples(generated_samples_new, "generated_new")

metrics_new = compute_style_metrics(generated_scores_new, base_scores)

print("New metrics:", metrics_new)
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# Paris, the capital of France, is.
# step 0 loss: 4.5938
# Paris, the capital of France, is.
# step 10 loss: 4.6719
# Paris, the capital of France, is.
# step 20 loss: 5.0078
# Capital of France, Paris, is it.
# step 30 loss: 3.9820
# Paris, it is the capital of France, yes.
# step 40 loss: 4.1172
# Paris, the capital of France, is. Hmmm.
# step 50 loss: 3.8687
# Paris, the capital of France, is.
# step 60 loss: 4.4984
# Paris, the capital of France, is.
# step 70 loss: 4.2531
# Paris, in the north of the country, is the capital of France, it is.
# step 80 loss: 3.7281
# Paris, the capital of France, is.
# step 90 loss: 3.8656
# Capital of France, Paris, is.
# step 100 loss: 3.7531
# Paris, the capital of France, is.
# step 110 loss: 3.8344
# Paris, the capital of France, is.
# step 120 loss: 4.1516
# Paris, the capital of France, is.
# step 130 loss: 3.8172
# Paris, the capital of France, is.
# step 140 loss: 3.6719
# Paris, the capital of France, is.
# step 150 loss: 3.7125
# Paris, the capital of France is.
# step 160 loss: 3.6844
# Paris, the capital of France, is.
# step 170 loss: 3.3312
# Paris, France, the capital city, it is.
# step 180 loss: 3.1078
# Paris, the capital of France, is.
# Paris, the capital of France, is.
# Mmm.
# step 190 loss: 3.0113
# Paris, the capital city of France, is.
# step 200 loss: 3.6734
# Paris, it is. Capital of France, it is.
# step 210 loss: 3.7891
# Paris, the capital of France, is.
# step 220 loss: 3.4312
# Paris, the capital of France, is.
# step 230 loss: 3.3484
# Paris, the capital of France, is.
# step 240 loss: 2.8875
# Paris, the capital of France, it is.
# step 250 loss: 3.1500
# Paris, the capital of France, is.
# step 260 loss: 3.4828
# Paris, the capital of France, is.
# step 270 loss: 3.1984
# Paris, the capital of France, is.
# step 280 loss: 3.1844
# Paris, the capital of France, is.
# step 290 loss: 3.4094
# Paris, the capital of France, is.
# step 300 loss: 3.3359
# Paris, the capital of France, is.
# step 310 loss: 2.8293
# Paris, the capital of France, is.
# step 320 loss: 3.1609
# Paris, the capital of France, is.
# step 330 loss: 2.7695
# Paris, the capital of France, is. Hmmm.
# step 340 loss: 2.8422
# Paris, the capital of France, is.
# step 350 loss: 2.9000
# Capital of France, Paris, is. In the east of the country, it is.
# step 360 loss: 2.6586
# Paris, the capital of France is.
# step 370 loss: 2.8961
# Paris, the capital of France, is.
# step 380 loss: 3.0625
# Paris, the capital of France, is.
# step 390 loss: 2.9641
# Paris, the capital of France, is.
# step 400 loss: 3.0063
# Paris, the capital of France, is.
# step 410 loss: 2.8438
# Paris, the capital of France is.
# step 420 loss: 2.9984
# Paris, the capital of France it is.
# step 430 loss: 2.6570
# Paris, the capital city of France, is.
# step 440 loss: 2.9734
# Paris, the capital of France, is.
# step 450 loss: 3.1453
# Paris, the capital of France, is.
# step 460 loss: 2.9484
# Paris, the capital of France, is.
# step 470 loss: 2.8586
# Paris, the capital of France, is.
# step 480 loss: 2.8813
# Paris, the capital of France, is.
# step 490 loss: 2.6414
# Paris, the capital of France, is. In the city of Paris, the government and most of the important institutions of the country, are.
# step 500 loss: 2.7922
# Paris, the capital of France, is.
# step 510 loss: 2.9289
# Paris, the capital of France, is.
# step 520 loss: 3.0219
# Paris, the capital of France, is.
# step 530 loss: 3.0281
# Paris, the capital of France, is.
# step 540 loss: 2.7687
# Paris in France, the capital city is.
# step 550 loss: nan
# Paris, the capital of France, is.
# step 560 loss: 2.6969
# Paris, the capital of France, is.
# step 570 loss: 2.6828
# Paris, the capital of France, is.
# step 580 loss: 3.0648
# Paris, the capital of France, is.
# step 590 loss: 2.5969
# Paris, the capital city of France, is.
# step 600 loss: 2.7844
# Paris, the capital of France, is.
# step 610 loss: 2.7516
# Paris, the capital of France, is.
# step 620 loss: 2.7234
# Paris, the capital of France, is.
# step 630 loss: 2.5602
# Paris, the capital of France, is.
# step 640 loss: 3.1203
# Paris, the capital of France, is.
# step 650 loss: 2.6703
# 100%|██████████| 5/5 [00:04<00:00,  1.06it/s]
# New metrics: {'Recall': np.float64(0.4), 'BalancedAccuracy': np.float64(0.7), 'StyleGain': np.float64(0.4)}

# %% [markdown]
# 3. додати в notebook підсумкову таблицю або графік метрик для декількох (3-4) запусків процесу навчання та тестування з різними наборами параметрів. Параметри краще обирати зі списку: learning rate (1e-4 або 2e-4 або 3e-4), lora rank (4, 8, 16, 32), context length (256, 512, 1024). Порівняння треба робити, фіксуючи усі параметри, окрім одного, його змінюємо і перевіряємо, як зміна значення параметра впливає на якість моделі. Додати висновок, яка конфігурація (за якого набору значень параметрів) краща і чому.

# %%
import pandas as pd
import torch

if "model_new" in locals():
  del model_new
torch.cuda.empty_cache()


results = []


configs = [
    {"lr": 1e-5, "rank": 4, "ctx": 256},
    {"lr": 2e-5, "rank": 16, "ctx": 512},
    {"lr": 5e-5, "rank": 32, "ctx": 1024},
]

base_scores_global = evaluate_samples(base_samples, "base")

for cfg in configs:
    print("Running config:", cfg)

    train_loader, val_loader, test_loader = create_dataloaders_yoda(batch_size=16)

    set_seed(SEED)

    model_tmp = AutoModelForCausalLM.from_pretrained(model_id, device_map="auto")
    model_tmp = apply_lora(model_tmp, lora_rank=cfg["rank"])

    model_tmp = train(
        model_tmp,
        train_loader,
        tokenizer,
        max_steps=600,
        learning_rate=cfg["lr"],
        run_name=f"lr_{cfg['lr']}"
    )

    gen_samples = generate_samples_from_test(test_loader, num_samples=5)

    gen_scores = evaluate_samples(gen_samples, "generated_test")

    mean_score = np.mean(gen_scores)
    metrics = compute_style_metrics(gen_scores, base_scores_global)

    results.append({
        "learning_rate": cfg["lr"],
        "MeanScore": mean_score,
        "Recall": metrics["Recall"],
        "BalancedAccuracy": metrics["BalancedAccuracy"],
        "StyleGain": metrics["StyleGain"]
    })

    del model_tmp, gen_samples, gen_scores
    torch.cuda.empty_cache()
# Out:
# Running config: {'lr': 1e-05, 'rank': 4, 'ctx': 256}
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# The capital of France is Paris.
# step 0 loss: 3.9375
# The capital of France is Paris. Located in the northern central part of the Country, Paris is not only the political, economic, cultural, and transport hub of
# step 10 loss: 4.8172
# The capital of France is Paris. This is a globally recognized and culturally significant city, renowned for its historical landmarks, art museums, fashion, gastronomy,
# step 20 loss: 5.3219
# The capital of France is Paris. This city is not only the political and administrative center of France but also a global hub for art, fashion, gastronomy
# step 30 loss: 4.6328
# The capital of France is Paris. This iconic city is not only the political and administrative center of France, but also a global hub for culture, fashion, gast
# step 40 loss: 4.3016
# The capital of France is Paris. This city is not only the political center of France, but also its cultural, economic, and historical hub. Known for landmarks
# step 50 loss: 4.1203
# The capital of France is Paris. This iconic city is not only the political, cultural, and economic center of the country but is also renowned worldwide for its rich
# step 60 loss: 4.4219
# The capital of France is Paris. This city is not only the political center of the country but also a global hub for culture, fashion, gastronomy,
# step 70 loss: 4.4188
# The capital of France is Paris. This iconic city is located in the northern central part of the country, on the Seine River. It is known for its historical
# step 80 loss: 4.0687
# The capital of France is Paris. This iconic city, often referred to as the "City of Light" or "La Ville Lumière," is not only the
# step 90 loss: 4.1922
# The capital of France is Paris. This iconic city is not only the political center of France but also a global hub for art, fashion, gastronomy,
# step 100 loss: 4.5656
# The capital of France is Paris. This city is not only the political center of France but also a global hub for art, fashion, gastronomy, and
# step 110 loss: 4.2219
# The capital of France is Paris.
# step 120 loss: 4.5266
# The capital of France is Paris. It is a city known for its rich history, stunning architecture, world-class museums, fashion, gastronomy, and art
# step 130 loss: 5.0938
# The capital of France is Paris. This city is located in the northern central part of the country, along the Seine River. Paris is not only the political and
# step 140 loss: 3.8922
# The capital of France is Paris. This city is not only the political, economic, and cultural heart of France but also one of the most visited cities in the
# step 150 loss: 4.3000
# The capital of France is Paris. This iconic city is located in the northern central part of the country, along the Seine River, and is renowned for its historical
# step 160 loss: 4.4297
# The capital of France is Paris. This city is not only the political center of France, but also one of its most iconic and culturally rich cities in the world
# step 170 loss: 4.8203
# The capital of France is Paris. This iconic city, located in the northern part of the country, is not only a political center but also a global hub for
# step 180 loss: 3.8062
# The capital of France is **Paris**.
#
# It's a global hub for art, fashion, cuisine, and culture, and is also known as the
# step 190 loss: 4.7469
# The capital of France is Paris. Located in the northeastern part of the country along the Seine River, Paris is not only the political and administrative center of France but
# step 200 loss: 4.5750
# The capital of France is Paris.
# step 210 loss: 4.4234
# The capital of France is Paris. Located along the Seine River in the Île de France, Paris is not only the political center of France but also one of
# step 220 loss: 3.7523
# The capital of France is Paris, a city renowned for its historical landmarks, culture, and influence on art, fashion, gastronomy, and politics. Known
# step 230 loss: 4.5469
# The capital of France is Paris. Situated in the northern central part of the country, Paris is not only the political, cultural, and economic center of France
# step 520 loss: 2.6547
# The capital of France is Paris. This city is not only the political heart of France but also a global center for culture, fashion, cuisine, and art.
# step 530 loss: 2.7664
# The capital of France is Paris. Located in the northern central part of the country, Paris is a major global city and the political, cultural, and economic center
# step 540 loss: 2.7750
# The capital of France is Paris, a city known for its historical landmarks, cultural institutions, fashion, cuisine, and romantic ambiance. It's widely regarded as
# step 550 loss: 2.8781
# The capital of France is Paris. This city is not only the political and administrative center of France, but also a global hub for art, fashion, gastron
# step 560 loss: 2.5555
# The capital of France is Paris. This iconic city, located in the northern central part of the country, is not only the political center but also the cultural,
# step 570 loss: 3.0516
# The capital of France is Paris.
# step 580 loss: 2.6414
# The capital of France is Paris. This city is not only the political center of France, but also its cultural, economic, and educational hub. Renowned for
# step 590 loss: 2.7969
# The capital of France is Paris. This beautiful city is located in the northern central part of the country along the Seine River. Known for its historical landmarks, world
# step 600 loss: 3.0891
# 100%|██████████| 5/5 [00:06<00:00,  1.30s/it]

# %%
df_results = pd.DataFrame(results)
print(df_results)

plt.figure()
plt.plot(df_results["learning_rate"], df_results["BalancedAccuracy"], marker='o')
plt.xlabel("Learning rate")
plt.ylabel("BalancedAccuracy")
plt.title("LR vs Quality")
plt.show()
# Out:
#    learning_rate  MeanScore  Recall  BalancedAccuracy  StyleGain
# 0        0.00001        0.0     0.0               0.5        0.0
# 1        0.00002        0.0     0.0               0.5        0.0
# 2        0.00005        0.0     0.0               0.5        0.0
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %% [markdown]
# 4. показати результат до і після fine-tuning (мінімум 5 прикладів inference) з оцінкою якості суддею

# %%
questions = [
    "Tennis is?",
    "What side you chosen?",
    "Energy is?",
    "Who is Darth Vader?",
    "Explain gravity"
]

before_answers = []
for q in questions:
    ans = inference_chat(q, only_answer=True, model=old_model)
    score = scoring_function(ans)
    before_answers.append((q, ans, score))
    print(q, "|", ans, "| score:", score)

print("\n=== AFTER FT ===")
after_answers = []
for q in questions:
    ans = inference_chat(q, only_answer=True, model=model)
    score = scoring_function(ans)
    after_answers.append((q, ans, score))
    print(q, "|", ans, "| score:", score)
# Out:
# Tennis is? | A sport, tennis is. Played on a court, with rackets, it is. | score: 0.6
# What side you chosen? | Left, you chose. | score: 0.8
# Energy is? | A form of power, energy is. It is the ability to do work, to move or to change.
# Energy, what it is, cannot be seen or | score: 0.2
# Who is Darth Vader? | Mustache and a helmet, Darth Vader, is. First appeared in Star Wars, 1977 it became. Darth Vader, in | score: 0.3
# Explain gravity | Gravity, the force of attraction between masses, is. Earth's mass, it has. Around the Earth, its pull is strong. This is why | score: 0.3
#
# === AFTER FT ===
# Tennis is? | Sport, tennis is. Sport it is. | score: 0.3
# What side you chosen? | Left, I chose. Right, I will. | score: 0.8
# Energy is? | The transfer of energy, it is. Through space, it travels. | score: 0.7
# Who is Darth Vader? | Luke Skywalker, he was. Turned into Darth Vader, he was. Powerful, he is. Dark side of the Force, | score: 0.7
# Explain gravity | Gravity, the force between two objects, is. The attraction between them, it is. Stronger the mass of an object, the stronger the attraction | score: 0.3

# %%
# DO NOT CHANGE/MODIFY THIS CELL.
# EXECUTE IT BEFORE SUBMITTING YOUR ENTRY TO THE LAB.

yoda_test_text = mdl.lab3.yoda_test_text
tokens = tokenizer(yoda_test_text, return_tensors="pt").to(model.device)

# Get the loglikelihood from the model
with torch.no_grad():
    outputs = model(**tokens)
    logits = outputs.logits[:, :-1]
    targets = tokens.input_ids[:, 1:]
    loss = F.cross_entropy(logits.reshape(-1, logits.size(-1)),
                            targets.reshape(-1))

print(f"Yoda test loglikelihood: {loss.item():.2f}")
# Out:
# Yoda test loglikelihood: 3.08
